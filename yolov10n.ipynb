# %% [markdown]
# <a href="https://colab.research.google.com/github/AadyaK-2248/YOLO-Comparisons/blob/main/yolov10n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 kB 49.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 111.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 84.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 49.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 91.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from ultralytics import YOLO
import cv2
import os
import shutil

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="WXeGOQsy4ADOtAwERpsY")
project = rf.workspace("ml-project-d0vep").project("indian-currency-detection-elfyf")
version = project.version(2)
dataset = version.download("Yolov9")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
#
# Version export complete for Yolov9 format
# ...
# Extracting Dataset Version Zip to Indian-Currency-Detection--2 in Yolov9:: 100%|██████████| 2714/2714 [00:01<00:00, 1762.06it/s]

# %%
from ultralytics import YOLO
model = YOLO('yolov10n.pt')
# Out:
# ...
# 100%|██████████| 5.59M/5.59M [00:00<00:00, 328MB/s]

# %%
# !ls /content
# Out:
# Indian-Currency-Detection--1  Indian-Currency-Detection--2  sample_data  yolov10n.pt

# %%
dataset_path = "/content/Indian-Currency-Detection--2/data.yaml"

# %%
# !yolo detect train data=/content/Indian-Currency-Detection--2/data.yaml model=yolov10n.pt epochs=100 imgsz=640
# Out:
# Ultralytics 8.3.103 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
import shutil
from google.colab import files

# Compress the folder to a zip file
shutil.make_archive('YOLO10n_runs', 'zip', '/content/runs')

# Download the zip file
files.download('YOLO10n_runs.zip')
