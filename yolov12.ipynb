# %% [markdown]
# <a href="https://colab.research.google.com/github/AadyaK-2248/YOLO-Comparisons/blob/main/yolov12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install ultralytics

# %%
from ultralytics import YOLO
import cv2
import os
import shutil

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="WXeGOQsy4ADOtAwERpsY")
project = rf.workspace("ml-project-d0vep").project("indian-currency-detection-elfyf")
version = project.version(1)
dataset = version.download("Yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
#
# Version export complete for Yolov11 format
# ...
# Extracting Dataset Version Zip to Indian-Currency-Detection--1 in Yolov11:: 100%|██████████| 2720/2720 [00:01<00:00, 1846.64it/s]

# %%
from google.colab import files
uploaded = files.upload()  # This will prompt a file upload dialog
# Out:
#      <input type="file" id="files-894931eb-b773-4b95-9b18-722a33e84073" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-894931eb-b773-4b95-9b18-722a33e84073">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from ultralytics import YOLO
model = YOLO('yolov12n.pt')

# %%
# !ls /content
# Out:
# Indian-Currency-Detection--1  sample_data  yolov12n.pt

# %%
# !find /content -name "data.yaml"
# Out:
# /content/Indian-Currency-Detection--1/data.yaml

# %%
dataset_path = "/content/Indian-Currency-Detection--1/data.yaml"  # Replace with the actual folder name

# %%
# !yolo detect train data=/content/Indian-Currency-Detection--1/data.yaml model=yolov12n.pt epochs=100 imgsz=640
# Out:
# Ultralytics 8.3.96 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
import shutil
from google.colab import files

# Compress the folder to a zip file
shutil.make_archive('YOLO12_runs', 'zip', '/content/runs')

# Download the zip file
files.download('YOLO12_runs.zip')

# %%
! nvidia-smi command
# Out:
# ERROR: Option command is not recognized. Please run 'nvidia-smi -h'.

# %%
# !nvidia-smi -h
# Out:
# NVIDIA System Management Interface -- v550.54.15
#
# NVSMI provides monitoring information for Tesla and select Quadro devices.
# The data is presented in either a plain text or an XML format, via stdout or a file.
# NVSMI also provides several management operations for changing the device state.
#
# Note that the functionality of NVSMI is exposed through the NVML C-based
# library. See the NVIDIA developer website for more information about NVML.
# Python wrappers to NVML are also available.  The output of NVSMI is
# not guaranteed to be backwards compatible; NVML and the bindings are backwards
# compatible.
#
# http://developer.nvidia.com/nvidia-management-library-nvml/
# http://pypi.python.org/pypi/nvidia-ml-py/
# Supported products:
# - Full Support
#     - All Tesla products, starting with the Kepler architecture
#     - All Quadro products, starting with the Kepler architecture
#     - All GRID products, starting with the Kepler architecture
# ...

# %%
# !nvidia-smi vgpu -h
# Out:
#     vgpu -- vGPU information.
#
#     nvidia-smi vgpu [OPTION1 [ARG1]] [OPTION2 [ARG2]] ...
#
#     [-h | --help]: Display help information
#     [-i | --id]: Specify the index, PCI bus ID, or UUID of one or more GPUs
#
#     [-q | --query]: Display information about currently running vGPUs
#     [-u | --utilization]: Display GPU engine usage by currently active vGPUs
#     [N/A | --gpm-metrics]: Display MIG level GPM Metrics
#                            Comma-separated list of GPM metrics to watch
#                            Available metrics:
#                                Graphics Activity    = 1
#                                SM Activity          = 2
#                                SM Occupancy         = 3
#                                Integer Activity     = 4
#                                Tensor Activity      = 5
#                                DFMA Tensor Activity = 6
#                                HMMA Tensor Activity = 7
# ...
