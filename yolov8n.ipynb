# %% [markdown]
# <a href="https://colab.research.google.com/github/AadyaK-2248/YOLO-Comparisons/blob/main/yolov8n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
import cv2
import os
import shutil

#!pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="WXeGOQsy4ADOtAwERpsY")
project = rf.workspace("ml-project-d0vep").project("indian-currency-detection-elfyf")
version = project.version(1)
dataset = version.download("Yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
#
# Version export complete for Yolov8 format

# %%
from google.colab import files
uploaded = files.upload()  # This will prompt a file upload dialog
# Out:
#      <input type="file" id="files-51c34e47-0954-434a-8dc8-2bed46273192" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-51c34e47-0954-434a-8dc8-2bed46273192">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 347MB/s]

# %%
# !ls /content
# Out:
# 'data (1).yaml'   data.yaml			 sample_data
# 'data (2).yaml'   Indian-Currency-Detection--1	 yolov8n.pt

# %%
# !find /content -name "data.yaml"
# Out:
# /content/data.yaml

# %%
dataset_path = "/content/drive/MyDrive/IndianCurrencyDetection.v1i.yolov8/data.yaml"  # Replace with the actual folder name

# %%
# !yolo detect train data=/content/drive/MyDrive/IndianCurrencyDetection.v1i.yolov8/data.yaml model=yolov8n.pt epochs=100 imgsz=640
# Out:
# Ultralytics 8.3.99 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
import shutil
from google.colab import files

# Compress the folder to a zip file
shutil.make_archive('YOLO8_runs', 'zip', '/content/runs')

# Download the zip file
files.download('YOLO8_runs.zip')

#!cp -r /content/runs/detect/train/weights /content/drive/MyDrive/

# %%
import yaml

with open("runs/detect/train/results.yaml", "r") as file:
    results = yaml.safe_load(file)
    print(results["hyperparameters"])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-097d72b9671f> in <cell line: 0>()
#       1 import yaml
#       2
# ----> 3 with open("runs/detect/train/results.yaml", "r") as file:
#       4     results = yaml.safe_load(file)
#       5     print(results["hyperparameters"])
#
# FileNotFoundError: [Errno 2] No such file or directory: 'runs/detect/train/results.yaml'
