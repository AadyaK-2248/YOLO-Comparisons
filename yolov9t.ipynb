# %% [markdown]
# <a href="https://colab.research.google.com/github/AadyaK-2248/YOLO-Comparisons/blob/main/yolov9t.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# !pip install roboflow
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="WXeGOQsy4ADOtAwERpsY")
project = rf.workspace("ml-project-d0vep").project("indian-currency-detection-elfyf")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Indian-Currency-Detection--2 in yolov8:: 100%|██████████| 2714/2714 [00:02<00:00, 1309.92it/s]

# %%
from ultralytics import YOLO
model = YOLO('yolov9t.pt')

# %%
# !ls /content
# Out:
# Indian-Currency-Detection--1  runs	   yolov10n.pt
# Indian-Currency-Detection--2  sample_data  yolov9t.pt

# %%
dataset_path = "/content/Indian-Currency-Detection--2/data.yaml"

# %%
# !yolo detect train data=/content/Indian-Currency-Detection--2/data.yaml model=yolov9t.pt epochs=100 imgsz=640
# Out:
# Ultralytics 8.3.103 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
import shutil
from google.colab import files

# Compress the folder to a zip file
shutil.make_archive('folder_name', 'zip', '/content/runs')

# Download the zip file
files.download('folder_name.zip')
